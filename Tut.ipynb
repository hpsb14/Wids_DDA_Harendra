# %%
import random

def get_choices():
    player_choice = input("Enter a choice (rock, paper, scissors:")
    options = ["rock", "paper", "scissors"]
    computer_choice = random.choice(options) 
    choices = {"player": player_choice, "computer": computer_choice}
    return choices

def check_result(player, computer):
    print("You chose" + player + "computer chose" + computer)
    print(f"You chose {player} ")
    if player == computer:
        return "draw"

choices = get_choices()
print(choices)


    #else if
# Out:
# Enter a choice (rock, paper, scissors:rock
# {'player': 'rock', 'computer': 'rock'}

# %%
dogs = ["Roger", 2, "Syd", True, "Quincy", 7]
print(dogs.pop(1))
# Out:
# 2

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot([2, 4, 6, 8, 10, 12])
plt.show()

# %matplotlib inline

# %%
plt.plot([2,5,8,10],[1,3,2,6])

# %%
plt.xlabel('some numbers')
plt.ylabel('some more labels')
# Out:
# Text(0, 0.5, 'some more labels')

# %%
plt.plot([1, 5, 9, 4], [7, 13, 8, 44])

# %%
plt.plot([2, 5, 8, 10],[1, 3, 2, 6],'hg')
plt.xlabel('some numbers')
plt.ylabel('some other labels')
plt.xlim(0, 12)
plt.ylim(0, 8)
# Out:
# (0.0, 8.0)

# %%
t = np.arange(0,10,0.5)

plt.plot(t, t,'blue' ,label='y=x')
plt.plot(t, t**2, 'red', label='y=x^2')
plt.plot(t, t**3, 'green', label='y=x^3')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# %%
names = ['a','b','c','d']
values = np.random.randint(0,50,4)

plt.bar(names, values, color='r')
plt.xlabel('Letter')
plt.ylabel('Number')
plt.title('Bar Graph')
# Out:
# Text(0.5, 1.0, 'Bar Graph')

# %%
values2 = np.random.randn(5000)
plt.hist(values2)
plt.xlabel('Number')
plt.ylabel('No.of occurence')
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7028\4121647919.py in <module>
#       1 data, freq, time = np.loadtxt('GW_data_file.csv', delimiter=',')
# ----> 2 print(GW_data_file.csv)
#
# NameError: name 'GW_data_file' is not defined

# %%
data, freq, time = np.loadtxt('GW_data_file.csv', delimiter=',')

plt.plot(time, data, 'r')
plt.xlabel('time')
plt.ylabel('strain')
plt.title('strain vs time')
plt.grid()
plt.show()
